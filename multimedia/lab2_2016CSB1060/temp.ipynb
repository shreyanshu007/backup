# %%
print ("hello")
# Out:
# hello

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.fftpack

# Number of samplepoints
N = 600
# sample spacing
T = 1.0 / 800.0
x = np.linspace(0.0, N*T, N)
y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x)
yf = scipy.fftpack.fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), N/2)

fig, ax = plt.subplots()
ax.plot(xf, 2.0/N * np.abs(yf[:N//2]))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.fftpack import fft
from scipy.fftpack import ifft

Fs = 100
f = 1

x = np.arange(Fs)

y = np.sin((2*np.pi*f*x)/Fs)

# plt.stem(x, fft(y))
# plt.plot(x, fft(y))

plt.plot(np.abs(np.fft.fftfreq(len(y), 1/len(y))), fft(y))
plt.show()

# %%
import sounddevice as sd
import soundfile as sf
from scipy.fftpack import fft
import numpy as np

filename = 'killbill.wav'
data, fs = sf.read(filename, dtype='float32')

y = []
for i in data:
    y.append(i[0])
x = np.arange(len(y))



# plt.stem(x, y)
plt.plot(np.abs(np.fft.fftfreq(len(y), 1.0/len(y))), fft(y))
plt.show()

# print(len(y))
# print(fs)


# Original Audio
# sd.play(data, fs)
# status = sd.wait(0)

# %%
import numpy as np
from scipy.fftpack import fft
import matplotlib.pyplot as plt
N = 600
T = 1/800
x = np.linspace(0.0, N*T,N)
a = np.sin(50.0 * 2.0*np.pi*x)
b = 0.5*np.sin(80.0 * 2.0*np.pi*x)
y = a + b
yf = fft(y)
Y = 2.0/N * np.abs(yf[0:int(N/2)])
X = np.linspace(0.0, 1.0/(2.0*T), N/2)
import matplotlib.pyplot as plt
plt.plot(x,y)
plt.grid()
plt.show()

# %%
import numpy as np
import soundfile as sf
import matplotlib.pyplot as plt

data, sampleRate = sf.read('killbill.wav', dtype='float32')

totSamples = data.shape[0]

#to extract one channel
data = data[0: totSamples,0:1]

print(data)

sp = np.abs(np.fft.fft(data))
freq = np.fft.fftfreq(totSamples, 1.0/totSamples)

plt.figure()
plt.plot(freq, sp)
plt.savefig('q3_saveplot')
plt.close()
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]
